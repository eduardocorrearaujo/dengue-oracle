# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the environment variables
api_key = os.getenv('API_KEY')

# %%
from mosqlient import upload_model

upload_model(

    #author_username ='eduardocorrearaujo', 

    name = "Dengue oracle - M1",

    description = "Baseline LSTM model without covariates, predicting the parameters of a log-normal distribution.",

    repository = "https://github.com/eduardocorrearaujo/dengue-oracle",

    implementation_language = "Python",

    disease = "dengue",

    temporal = True,

    spatial = False,

    categorical = False,

    adm_level = 1, # National

    time_resolution = "week",
    
    sprint = True, 

    api_key = api_key

    )
# Out:
# Dengue oracle - M1

# %%
upload_model(

    #author_username ='eduardocorrearaujo', 

    name = "Dengue oracle - M2",

    description = "Baseline LSTM model with covariates, predicting the parameters of a log-normal distribution.",

    repository = "https://github.com/eduardocorrearaujo/dengue-oracle",

    implementation_language = "Python",

    disease = "dengue",

    temporal = True,

    spatial = False,

    categorical = False,

    adm_level = 1, # National

    time_resolution = "week",
    
    sprint = True, 

    api_key = api_key

    )
# Out:
# Dengue oracle - M2
